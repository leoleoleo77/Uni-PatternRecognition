# %%
import dataMethods
from matplotlib import pyplot as plt 
import numpy as np

# %%
# Ιστογράμματα συχνοτήτων των τιμών longitude
array = dataMethods.Longitude_column()
fig, axs = plt.subplots(figsize=(10, 5))
hist = axs.hist(array, np.arange(0, 1, 0.005), edgecolor='black', linewidth=0.1, density=True)
axs.set_title('Ιστογράμματα συχνοτήτων των τιμών longitude')
plt.show()

# %%
array = dataMethods.Latitude_column()
fig, axs = plt.subplots(figsize=(10, 5))
hist = axs.hist(array, np.arange(0, 1, 0.005), edgecolor='black', linewidth=0.1, density=True)
axs.set_title('Ιστογράμματα συχνοτήτων των τιμών latitude')
plt.show()

# %%
array = dataMethods.Housing_median_age_column()
fig, axs = plt.subplots(figsize=(10, 5))
hist = axs.hist(array, np.arange(0, 1, 0.02), edgecolor='black', linewidth=0.1, density=True) #numpy to create bins over range
axs.set_title('Ιστογράμματα συχνοτήτων housing των τιμών median_age')
plt.show()

# %%
array = dataMethods.Total_rooms_column()
fig, axs = plt.subplots(figsize=(10, 5))
hist = axs.hist(array, np.arange(0, 1, 0.005), edgecolor='black', linewidth=0.1, density = True) #numpy to create bins over range
axs.set_title('Ιστογράμματα συχνοτήτων των τιμών total_rooms')
plt.show()

# %%
array = dataMethods.Total_bedrooms_column()
fig, axs = plt.subplots(figsize=(10, 5))
hist = axs.hist(array, np.arange(0, 1, 0.005), edgecolor='black', linewidth=0.1, density = True) #numpy to create bins over range
axs.set_title('Ιστογράμματα συχνοτήτων των τιμών total_bedrooms')
plt.show()

# %%
array = dataMethods.Population_column()
fig, axs = plt.subplots(figsize=(10, 5))
hist = axs.hist(array, np.arange(0, 1, 0.005), edgecolor='black', linewidth=0.1, density = True) #numpy to create bins over range
axs.set_title('Ιστογράμματα συχνοτήτων των τιμών population')
plt.show()

# %%
array = dataMethods.Households_column()
fig, axs = plt.subplots(figsize=(10, 5))
hist = axs.hist(array, np.arange(0, 1, 0.005), edgecolor='black', linewidth=0.1, density=True) #numpy to create bins over range
axs.set_title('Ιστογράμματα συχνοτήτων των τιμών households')
plt.show()

# %%
array = dataMethods.Median_income_column()
fig, axs = plt.subplots(figsize=(10, 5))
hist = axs.hist(array, np.arange(0, 1, 0.005), edgecolor='black', linewidth=0.1, density=True) #numpy to create bins over range
axs.set_title('Ιστογράμματα συχνοτήτων των τιμών median_income')
plt.show()

# %%
array = dataMethods.Median_house_value_column()
fig, axs = plt.subplots(figsize=(10, 5))
hist = axs.hist(array, np.arange(0, 1, 0.005), edgecolor='black', linewidth=0.1, density=True)
axs.set_title('Ιστογράμματα συχνοτήτων των τιμών median_house_value')
plt.show()

# %%
array = [0, 0, 0 ,0 ,0]
ocean_proximity_data = [0, 0, 0 ,0, 0]
num_of_data = 0
tempdata = dataMethods.Ocean_proximity_column()
for i in range(5):
    ocean_proximity_data[i] = 1
    for data in tempdata:
        if data == [1, 0, 0 ,0, 0]:
            num_of_data += 1
    array[i] = num_of_data
    num_of_data = 0
    ocean_proximity_data[i] = 0
data = {'NEAR BAY': array[0], '<1H OCEAN': array[1], 'INLAND': array[2], 'NEAR OCEAN': array[3] ,'ISLAND': array[4]}
names = list(data.keys())
values = list(data.values())
fig, axs = plt.subplots(figsize=(9, 3))
axs.set_title('Ιστογράμματα συχνοτήτων των τιμών median ocean_proximity')
axs.bar(names, values)
# Out:
# <BarContainer object of 5 artists>

# %%
array = dataMethods.Median_house_value_column()
fig, axs = plt.subplots(figsize=(10, 5))
hist = axs.hist(array, np.arange(0, 1, 0.005), edgecolor='black', linewidth=0.1, density=True)
axs.set_title('Ιστογράμματα συχνοτήτων των τιμών median_house_value')
plt.show()

# %%
# set the size of the graph
fig, axs = plt.subplots(figsize=(10, 5))

# median house value stuff
array1 = dataMethods.Median_house_value_column()
array1_x_values = np.arange(0, 0.995, 0.005)
array1_y_values = axs.hist(array1, np.arange(0, 1, 0.005), density=True)[0]

# median house age stuff
array2 = dataMethods.Housing_median_age_column()
array2_x_values = np.arange(0, 0.98, 0.02)
array2_y_values = axs.hist(array2, np.arange(0, 1, 0.02), density=True)[0]

# total rooms stuff
array3 = dataMethods.Median_income_column()
array3_x_values = np.arange(0, 0.995, 0.005)
array3_y_values = axs.hist(array3, np.arange(0, 1, 0.005), density=True)[0]

# plt.close() so that the histograms created to get the y values wont show
plt.close()
# Plotting the specified values
plt.plot(array1_x_values, array1_y_values, marker='o', markersize=2, color='green', label="Median House Value")  
plt.plot(array2_x_values, array2_y_values, marker='o', markersize=2, color='orange', label="Median House Age")  
plt.plot(array3_x_values, array3_y_values, marker='o', markersize=2, color='purple', label="Median Income")  
# the the origin of the axis to be (0,0)
plt.xlim([0, 1]) 
plt.ylim([0, max(array3_y_values)])
plt.legend()
plt.title('Relation between the value of the house, the age of the house and the income of its owners')
plt.grid(True)
plt.show()

# %%
# set the size of the graph
fig, axs = plt.subplots(figsize=(10, 5))

# population stuff
array1 = dataMethods.Population_column()
array1_x_values = np.arange(0, 0.995, 0.005)
array1_y_values = axs.hist(array1, np.arange(0, 1, 0.005), density=True)[0]

# total rooms stuff
array2 = dataMethods.Total_rooms_column()
array2_x_values = np.arange(0, 0.995, 0.005)
array2_y_values = axs.hist(array2, np.arange(0, 1, 0.005), density=True)[0]

# total bed rooms stuff
array3 = dataMethods.Total_bedrooms_column()
array3_x_values = np.arange(0, 0.995, 0.005)
array3_y_values = axs.hist(array3, np.arange(0, 1, 0.005), density=True)[0]

# plt.close() so that the histograms created to get the y values wont show
plt.close()
# Plotting the specified values
plt.plot(array1_x_values, array1_y_values, marker='o', markersize=2, color='green', label="Population")  
plt.plot(array2_x_values, array2_y_values, marker='o', markersize=2, color='red', label="Total Rooms")  
plt.plot(array3_x_values, array3_y_values, marker='o', markersize=2, color='blue', label="Total Bed Rooms")  
# the the origin of the axis to be (0,0)
plt.xlim([0, 1]) 
plt.ylim(ymin=0.0)
plt.legend()
plt.title('Relation between the population, the total rooms, and the total bed rooms')
plt.grid(True)
plt.show()
